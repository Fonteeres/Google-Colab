# %% [markdown]
# <a href="https://colab.research.google.com/github/Fonteeres/Google-Colab/blob/master/RegresionyClasificacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # importo el Data Set

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
import numpy as np
df_vino = pd.read_csv('/content/drive/MyDrive/Aprendizaje_Automatico_1/set_datos/winequality-white.csv', sep=';')
df_vino
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# #Separo X e Y con Pandas

# %%
df_vino_x = df_vino.drop(["quality"], axis = 1)
df_vino_x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_vino_y = df_vino['quality']
df_vino_y
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 4893    6
# 4894    5
# 4895    6
# 4896    7
# 4897    6
# Name: quality, Length: 4898, dtype: int64

# %% [markdown]
# # Separo En X_train, X_test, y_train e y_test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_vino_x, df_vino_y, test_size=0.2, random_state=123)

# %% [markdown]
# # Arbol de Clasificacion

# %%
from sklearn.tree import DecisionTreeClassifier
Arbol = DecisionTreeClassifier(random_state=45)

# %%
Arbol.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=45)

# %%
Prediccion = Arbol.predict(X_test)
df_Prediccion = pd.DataFrame({'Actual':y_test, 'Prediccion':Prediccion})
df_Prediccion.head(70)
# Out:
#       Actual  Prediccion
# 1088       6           6
# 4366       6           6
# 92         7           7
# 2901       7           7
# 2330       6           6
# ...      ...         ...
# 1683       7           7
# 4303       6           6
# 2277       6           6
# 4747       6           7
# 2957       6           7
#
# [70 rows x 2 columns]

# %%
score = Arbol.score(X_test, y_test)
score
# Out:
# 0.5877551020408164

# %% [markdown]
# # Random Forrest

# %% [markdown]
# LLamo al modelo

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

# %% [markdown]
# Creo y entreno el Modelo

# %%
MRandom = RandomForestRegressor ()
MRandom.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# Creo una Prediccion

# %%
RandomPredict = MRandom.predict(X_test)

# %% [markdown]
# Evaluo

# %%
df_RMFR_Predict = pd.DataFrame({'Actual':y_test, 'Prediccion':RandomPredict})
df_RMFR_Predict.head(70)
# Out:
#       Actual  Prediccion
# 1088       6        5.97
# 4366       6        6.58
# 92         7        6.78
# 2901       7        6.88
# 2330       6        5.43
# ...      ...         ...
# 1683       7        6.98
# 4303       6        6.14
# 2277       6        6.38
# 4747       6        6.08
# 2957       6        6.40
#
# [70 rows x 2 columns]

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier(n_neighbors=3)

# %%
KNN.fit(X_train,y_train)
KNN_Predict = KNN.predict(X_test)
df_KNN_Predict = pd.DataFrame({'Actual':y_test, 'Prediccion':KNN_Predict})
df_KNN_Predict.head(70)
# Out:
#       Actual  Prediccion
# 1088       6           5
# 4366       6           6
# 92         7           6
# 2901       7           6
# 2330       6           6
# ...      ...         ...
# 1683       7           7
# 4303       6           7
# 2277       6           6
# 4747       6           6
# 2957       6           6
#
# [70 rows x 2 columns]

# %%
KNN_score = KNN.score(X_test, y_test)
KNN_score
# Out:
# 0.49081632653061225

# %%
k_range = np.arange(1,20)
df_Resultados = pd.DataFrame(columns=['Rango','Resultado'])
for k in k_range:
  KNN2 = KNeighborsClassifier(n_neighbors=k)
  KNN2.fit(X_train,y_train)
  score = KNN2.score(X_test,y_test)
  df_Resultados.append({'Rango': k}, ignore_index=True) 
  df_Resultados.append({'Resultado': score}, ignore_index=True)
  
df_Resultados
# Out:
# Empty DataFrame
# Columns: [Rango, Resultado]
# Index: []

# %% [markdown]
# # SVM Regresion

# %%
from sklearn import svm

# %% [markdown]
# Creo el Modelo de SVMC y lo entreno

# %%
Regresion = svm.SVC()
Regresion.fit(X_train,y_train)
# Out:
# SVC()

# %% [markdown]
# Hago la prediccion

# %%
Predic_SVC = Regresion.predict(X_test)
df_SVC_Regresion = pd.DataFrame({"Prediccion" : Predic_SVC, "Y_test" : y_test})
df_SVC_Regresion
# Out:
#       Prediccion  Y_test
# 1088           6       6
# 4366           6       6
# 92             6       7
# 2901           6       7
# 2330           6       6
# ...          ...     ...
# 4189           6       5
# 3341           6       6
# 1055           6       5
# 3114           6       6
# 654            6       7
#
# [980 rows x 2 columns]

# %% [markdown]
# Mido el Score

# %%
Regresion.score(Regresion.predict(X_test),y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   "X does not have valid feature names, but"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-ca68fb188f45> in <module>()
# ----> 1 Regresion.score(Regresion.predict(X_test),y_test)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     649         from .metrics import accuracy_score
#     650
# --> 651         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     652
#     653     def _more_tags(self):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     789             y = np.argmax(self.decision_function(X), axis=1)
#     790         else:
# --> 791             y = super().predict(X)
# ...
